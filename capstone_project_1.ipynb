# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanasalim256/cape-stone-project-/blob/main/capstone_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Project Name** -  ****HOTEL BOOKING Analysis::****
# ![176-1760489_svg-library-download-wave-hatenylo-com-png-transparent.png](data:image/png;base64,...)

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual (Sana Fatima)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The purpose of Hotel Booking System is to automate the existing manual system by the help of computerized equipments and full-fledged computer software, fulfillingtheir requirements, so that their valuable data/information can be stored for a longer period with easy accessing and manipulation of the same. The required software and hardware are easily available and easy to work with.
#
#
# *   Hotel Booking System, as described above, can lead to error free, secure,reliable and fast management system.
# *   The aim is to automate its existing manual system by the help of computerizedequipments and full-fledged computer software, fulfilling their requirements, so that their valuable data/information can be stored for a longer period with easy accessing and manipulation of the same.
#
#
# *   Basically the project describes how to manage for good performance and better services for the clients.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# **Bussiness Problem OverView**
#
#  System analysis is a process of gathering and interpreting facts, diagnosing problems and the information about the Hotel Booking System to recommend improvements on the system. It is a problem solving activity that requires intensive communication between the system users and system developers.
#
#  **Objective of Project on Hotel Booking System:**
#
# The main objective of the Project on Hotel Booking System is to manage the details of Hotel, Rooms, Services, Payments, Bookings.
#
# It manages all the information about Hotel, Customers, Bookings, Hotel. The project is totally built at administrativeend and thus only the administrator is guaranteed the access. The purpose of the project is to build an application program to reduce the manual work for managing the Hotel, Rooms, Customers, Services. It tracks all the details about the Services,Payments, Bookings.

# %% [markdown]
# **Modules of Hotel Booking System:**
#
#
# 1.**Hotel Management Module**: Used for managing the Hotel details.
#
# 2.
# **Bookings Module** : Used for managing the details of Bookings
#
# 3.
# **Customers Module** : Used for managing the details of Customers
#
#
# 4.
# **Rooms Management Module**: Used for managing the information and details ofthe Rooms.
#
# 5.
# **Services Module** : Used for managing the Services details
#
# 6.
# **Payments Module** : Used for managing the Payments informations
#
# 7.
# **Login Module**: Used for managing the login details
#
# 8.
# **Users Module** : Used for managing the users of the system

# %% [markdown]
# Answer Here.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import RcParams
from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# %%
path='/content/Hotel Bookings.xlsx'

# %%
df=pd.read_excel(path)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %%
df.describe()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(),cbar=False)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# A logical system is built which fulfils the given requirements. Design phase of software development deals with transforming the clients’s requirements into alogically working system.
# The above dataframe has 119390 rows,32 columnsand duplicate values is 31994. and missing values also have 128,933

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe(include='all')

# %% [markdown]
# ### Variables Description

# %%
for i in df.columns.tolist():
  print("no. of unique values in ",i,"is",df[i].nunique(),".")

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#create a copy of the current dataset and assigning to df
df=df.copy()
#drop the duplicates from the dataset
df=df.drop_duplicates()
#reset the index, because we droped some rows
df=df.reset_index(drop=True)

df.info()

# %%
# Null Sorting values in ascending order
df.isnull().sum().sort_values(ascending=False)[:5]

# %% [markdown]
# finding unique values of each

# %%
# Write your code to make your dataset analysis ready.
# Create a copy of the current dataset and assigning to df
df=df.copy()
# Checking Shape of True Value
print("No. of customers hotel : -",len(df[df['hotel']==True]))
# Assigning customers hotel data to variable
df_hotel=df[(df['hotel']==True)]

# %%
# single unique value finding below

# %%
df['company'].unique()

# %%
#multiple unique values finding using loop function
for col in df.columns.tolist():
  print("unique values in ",col,"is",df[col].unique())

# %%
# finding function groupby with  Country Dataframe
pd.DataFrame(df.groupby('country').size())

# %%
#finding multiple colums with groupby function
pd.DataFrame(df.groupby(['country','children','company','agent','reserved_room_type']).size())

# %%
#  find the mean and median for a dataset that includes both adults and other categories, possibly comparing them
get_mean_median=df.groupby(['country','children','company','agent','reserved_room_type']).agg({'adults':['mean','median']})
get_mean_median

# %%
# here using groupby function and getting mean and median for children with company
get_mean_median=df.groupby('children').agg({'company':['mean','median']})
get_mean_median

# %%
#  here using groupby function and getting mean and median for agent with company
get_mean_median=df.groupby('agent').agg({'company':['mean','median']})
get_mean_median

# %%
# here using groupby function getting mean and median for reserved_room_type with company
get_mean_median=df.groupby('reserved_room_type').agg({'company':['mean','median']})
get_mean_median

# %%
# here using groupby function getting mean and median for babies with company
get_mean_median=df.groupby('babies').agg({'company':['mean','median']})
get_mean_median

# %%
# find how many arrival date year's
df['arrival_date_year'].unique()

# %%
# find out arrival month and arrival date month
df['arrival_month']=df['arrival_date_month'].map({'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,'November':11,'December':12})
df.head()

# %%
# showing tail of a data set
df.tail()

# %%
# finding unique date month
df['arrival_date_month'].unique()

# %%
# finding unique date_date_of_month
df['arrival_date_day_of_month'].unique()

# %%
# DataFrame showing about arrival date year and reservation status date
pd.DataFrame(df.groupby('arrival_date_year')['reservation_status_date'].value_counts().reset_index(name="Count"))

# %%
# showing scatter plot using above DataFrame about arrivalyear & reservation status
cdd = sns.scatterplot(x="arrival_date_year", y="reservation_status_date", hue="hotel", data=df)

# %%
# Function to get all arrival_date_year mean & median while passing arrival_date_year and dataframe.
def get_mean_median(df,arrival_date_year):
  '''
  This function returns the mean and median of the whole dataset for a particular area code.

  '''
  try:
    return pd.concat([df[(df['is_canceled']==True)&(df['arrival_date_year']==arrival_date_year)].describe().iloc[1],
            df[(df['is_canceled']==True)&(df['arrival_date_year']==arrival_date_year)].describe().iloc[5]],axis=1).rename(columns={"75%":"median"}).fillna("-")
  except:
    print("arrival_date_year")

# %%
# Getting Mean Median for arrival_date_year 2015
get_mean_median(df=df,arrival_date_year=2015)

# %%
# Getting Mean Median for arrival_date_year 2016
get_mean_median(df=df,arrival_date_year=2016)

# %%
# Getting Mean Median for arrival_date_year 2017
get_mean_median(df=df,arrival_date_year=2017)

# %%
# To determine which country sends the most guests to a hotel through agents based on a dataset.
pd.DataFrame(df.groupby('country')['agent'].value_counts( ).reset_index(name="count"))

# %%
data=datasetcdd = sns.scatterplot(x="Total day minutes", y="Total day charge", hue="Churn", )

# %%
#To calculate the mean and median number of guests per country and per agent using a pandas DataFrame
get_mean_median=df.groupby('country').agg({'agent':['mean','median']})
get_mean_median

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Manipulations Done:
# Data Aggregation:
#
# Grouped and Counted Data: Aggregated data by arrival_date_year and is_canceled to calculate the number of cancellations and non-cancellations for each year.
# perform mean and median operations on a dataset, you typically follow these steps using a library like pandas in Python.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 pie chart on Dependant variable i.e., hotel

# %%
# Chart - 1 visualization code
# Chart - 1 visualization code
# Dependant Column Value Counts
print(df.hotel.value_counts())
print(" ")
# Dependant Variable Column Visualization
df['hotel'].value_counts()
df['hotel'].value_counts().plot(kind='pie',
                              figsize=(15,6),
                               autopct="%1.1f%%",
                               startangle=90,
                               shadow=True,
                                colors=['red','grey'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# The pie chart was chosen for visualizing the distribution of values in the 'hotel' column because of the following reasons:
# 1. Proportional Representation
# 2.Simplicity
# 3.Clear Comparison
# 4. Effective for Categorical Data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# From the pie chart, we see the following information:
#
# Total Number of Hotels: 87,396
# City Hotels: 53,428
# Resort Hotels: 33,968
# Key Insights:
# City Hotels:
#
# They represent the majority of the dataset, accounting for 53,428 out of the 87,396 hotels, which is about 61.1% of the total.
# Resort Hotels:
#
# They make up 33,968 of the total hotels, which is approximately 38.9%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# The data shows that city hotels are more prevalent than resort hotels. Specifically, city hotels make up over half of all the hotels in the dataset, while resort hotels form a significant but smaller portion.

# %% [markdown]
# #### Chart - 2
# Number of booking cancel in dataset

# %%
# Chart - 2 visualization code

# %%
print(df.is_canceled.value_counts())
print(" ")
# Dependant Variable Column Visualization
df['is_canceled'].value_counts().plot(kind='pie',
                              figsize=(10,5),
                               autopct="%1.1f%%",
                               startangle=90,
                               shadow=True,
                                      colors=['pink','yellow'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.The pie chart was chosen for visualizing the distribution of values in the 'hotel' column because of the following reasons:
#
# Proportional Representation
# Simplicity
# Clear Comparison
# Effective for Categorical Data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The output you've provided shows the count of cancellations and non-cancellations from the is_canceled column in your dataset:0 (Not Canceled): 63,371 bookings 1 (Canceled): 24,025 bookings
# Cancellation Rate:
#
# The cancellation rate can be computed as a proportion of the total bookings.
# Total Bookings = 63,371 (not canceled) + 24,025 (canceled) = 87,396
# Cancellation Rate = 24,025 / 87,396 ≈ 27.5%
#
# Comparison:
#
# The number of non-canceled bookings (63,371) is significantly higher than the number of canceled bookings (24,025).
# This indicates that cancellations, while present, represent a smaller proportion of the total bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
# Positive Business Impact
# 1. Identifying Cancellations Proportion:
# Understanding Cancellation Rates
# Improving Customer Experience
# 2. Optimizing Booking Processes:
# Data-Driven Decisions
# Resource Allocation
# Revenue Forecasting
#
# Positive Impact:
# Insights into booking cancellations can drive improvements in customer service, booking processes, and resource management, leading to increased revenue and operational efficiency.
#
# Negative Growth Insights
# 1. High Cancellation Rate:
# Impact on Revenue:
# Operational Disruptions:
# 2.Potential Causes: If cancellations are due to issues such as poor customer experience or service quality, it can damage the business’s reputation. Negative reviews and customer dissatisfaction can lead to decreased trust and fewer future bookings.
# Need for Improvements: High cancellations might indicate underlying problems that need to be addressed, such as inadequate booking systems, poor communication, or issues with customer service.
# Negative Impact:
# High cancellation rates can result in lost revenue, operational inefficiencies, and damage to the business’s reputation. Identifying and addressing the root causes of cancellations is crucial to mitigating these negative effects and fostering business growth.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3
# The bar chart provides a clear visual representation of the distribution of meal types in dataset

# %%
# Chart - 3 visualization code

# %%
df['meal'].value_counts().plot(kind='line', figsize=(10,6))
plt.title('Distribution of Meal Types')
plt.xlabel('Meal Type')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)


plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# Line Chart: While not the most conventional choice for categorical data, it may be used to explore different perspectives or trends if there is a logical sequence or time component.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# If the line chart shows meal types like Breakfast, Lunch, Dinner, and None, you might observe:
#
# Breakfast has the highest number of bookings, suggesting it is the most popular meal type among customers.
# Dinner might have a moderate number of bookings, indicating it is also popular but less so than breakfast.
# Lunch has fewer bookings compared to breakfast and dinner, suggesting it is less preferred.
# None might have the lowest number of bookings,showing that few customers opt for no meal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Answer Here
# Positive Impact: Leveraging insights from meal type distribution can help optimize offerings, improve marketing strategies, allocate resources efficiently, and enhance customer satisfaction.
#
# Negative Impact: Focusing on less popular meal types could lead to increased costs, inefficiencies, and potential negative impacts on customer satisfaction and brand perception.
# To maximize positive impacts and mitigate negative effects, the business should use the insights to align offerings with customer preferences, streamline operations, and focus on high-demand meal types while reassessing or modifying those with lower demand.

# %% [markdown]
# #### Chart - 4
# You’ll see a list of market segments along with the number of bookings associated with each segment, which helps in understanding the distribution of bookings across different channels.

# %%
# Chart - 4 visualization code

# %%
print(df.market_segment.value_counts())
print(" ")
# Dependant Variable Column Visualization
df['market_segment'].value_counts().plot(kind='bar')
plt.title('Market Segment Distribution')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.bar(df['market_segment'].value_counts().index, df['market_segment'].value_counts().values)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it offers a clear, effective way to compare the number of bookings across various market segments. It helps in understanding which segments perform better, guiding strategic decisions, and improving overall business strategies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# The bar chart provides a visual representation of the effectiveness and popularity of different market segments in generating bookings. By analyzing this chart, you can identify which market segments are performing well, which are underperforming, and make informed decisions to optimize marketing strategies, resource allocation, and overall business growth.
# Online TA has the highest number of bookings (51,618),

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Positive Impact:
# Insights from the market segment distribution help in optimizing marketing strategies, efficiently allocating resources, and making informed strategic decisions. By leveraging data to focus on high-performing segments and improve underperforming ones, you can drive growth and enhance business performance.
#
# Negative Impact:
# Insights that reveal underperformance in certain segments can indicate potential issues such as missed revenue opportunities, wasted resources, or strategic missteps. Addressing these issues proactively is crucial to avoiding negative growth and ensuring balanced business development.

# %% [markdown]
# #### Chart - 5
# Generates a box plot for the lead_time

# %%
# Chart - 5 visualization code

# %%
#df.boxplot(column='lead_time')
plt.figure(figsize=(10, 6))
df.boxplot(column='lead_time')
plt.title('Box Plot of Lead Time')
plt.xlabel('Lead Time')
plt.ylabel('Days')
plt.show()

# %% [markdown]
# ##### 1.Why did you pick the specific chart?
# The box plot was chosen because it provides a comprehensive overview of the distribution, central tendency, and variability of the lead_time data. It allows for easy identification of outliers and helps in understanding the overall data spread, which is crucial for analyzing lead times and making informed business decisions.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# 1.Median Lead Time: Provides a central
# reference for typical lead times.
#
# 2.Variability: The IQR shows the spread of lead times among most bookings, indicating consistency or variability.
#
# 3.Outliers: Highlights unusually long or short lead times that deviate significantly from the norm.
#
# 4.Range: The whiskers indicate the typical range of lead times, helping to understand what is considered normal.
#
# 5.Skewness: The shape and spread of the box plot can reveal skewness in the data distribution.
# These insights are valuable for understanding lead time patterns, making informed decisions about booking strategies, and identifying areas for improvement or further investigation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Overall, leveraging insights from lead time data can positively impact business operations by improving forecasting, resource management, and customer experience. However, it’s important to address any negative insights related to variability or outliers to mitigate potential operational and customer-related issues.

# %% [markdown]
# #### Chart - 6
# improving the overall effectiveness of the data visualization.

# %%
# Chart - 6 visualization code

# %%
plt.figure(figsize=(12, 6))  # Optional: Adjust size for better readability
distribution_channel_counts = df['distribution_channel'].value_counts()
plt.bar(distribution_channel_counts.index, distribution_channel_counts.values, color='skyblue')
plt.title('Distribution Channel Distribution')
plt.xlabel('Distribution Channel')
plt.ylabel('Number of Bookings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# I chose the bar chart because it is effective for comparing the number of bookings across different distribution channels. Bar charts are particularly useful for categorical data, where the goal is to compare the frequency or count of different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# If the bar chart shows that the majority of bookings come from "Online Travel Agents" (OTA) and a smaller number from "Direct" channels, it suggests that the hotel relies heavily on OTAs for bookings. This might indicate that the hotel's direct booking platform needs improvement or more promotion.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# 1.Optimized Marketing Spend: By identifying the most popular booking channels, the hotel can allocate marketing budgets more effectively. Focusing on high-performing channels can increase bookings and revenue.
#
# 2.Improved Customer Experience: Understanding customer preferences can help the hotel enhance the user experience on the most popular platforms. This can lead to increased customer satisfaction and repeat business.
#
# Potential Negative Growth Insights:
# Over-Reliance on a Single Channel: If the hotel is heavily reliant on one booking channel, any changes in that channel’s policies, algorithms, or popularity could negatively impact bookings. For example, if an OTA increases its commission rates or changes its ranking algorithm, the hotel might see a sudden drop in bookings.
# Justification: Over-reliance on a single channel is risky because it makes the business vulnerable to external changes that are beyond its control. Diversifying booking channels can mitigate this risk.

# %% [markdown]
# #### Chart - 7
# Cancellation Status Distribution by Year

# %%
# Chart - 7 visualization code

# %%
print(df.groupby('arrival_date_year')['is_canceled'].value_counts())
print(" ")
# Dependant Variable Column Visualization
df.groupby('arrival_date_year')['is_canceled'].value_counts().plot(kind='bar')
plt.title('Cancellation Status Distribution by Year')
plt.xlabel('Year')
plt.ylabel('Cancellation Status')
percentages=df.groupby('arrival_date_year')['is_canceled'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# However, if you need to compare the exact counts or see trends over time more clearly, other charts like bar plots or line charts might be more appropriate. They can provide a clearer view of changes in counts and trends across multiple years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# Yearly Cancellation Rates:
#
# In 2015, the cancellation rate is relatively lower compared to the total number of bookings, with 2704 cancellations out of 10609 bookings.
# In 2016, the cancellation rate is higher, with 11208 cancellations out of 31183 bookings, indicating a significant increase in cancellations.
# In 2017, although the number of cancellations (10113) is slightly lower than in 2016, it remains substantial compared to the total number of bookings (21579).
# Increase in Cancellations:
#
# The data shows a noticeable increase in both the number of cancellations and the total bookings from 2015 to 2016, suggesting a trend where cancellations became more frequent in 2016. The trend remains high in 2017, though it slightly decreases from 2016.
# Proportional Insight:
#
# The proportion of cancellations relative to the total bookings is highest in 2016, followed by 2017 and then 2015. This indicates that cancellations became a more significant issue over time, particularly in 2016.

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# High Cancellation Rates in 2016 Insights Leading to Negative Growth.The significant increase in cancellations in 2016 (11,208 cancellations out of 31,183 bookings) compared to 2015 (2,704 cancellations out of 10,609 bookings) and 2017 (10,113 cancellations out of 21,579 bookings) could indicate a problem area.
# While the insights can lead to strategies that improve business outcomes, they also highlight potential issues that need addressing. Negative growth could stem from customer dissatisfaction, operational problems, or external market factors, all of which require targeted actions to mitigate and turn the situation around.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #### Chart - 8 pair plot

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# A pair plot, created using Seaborn's sns.pairplot(), is a powerful tool for visualizing relationships between multiple variables in a dataset.A pair plot is an essential tool for anyone looking to perform a thorough exploratory data analysis. It helps in understanding the intricate relationships and distributions within a dataset, making it easier to draw meaningful insights and prepare the data for further analysis or modeling.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?To determine the insights from a pair plot, let's consider a practical example using the Hotel dataset. By examining the pair plot, you can draw several meaningful insights about the relationships between the variables.
# From the pair plot of the hotel dataset, we can derive the following key insights:
# 1.Feature Engineering: Focus on petal measurements for building classification models, as they provide better differentiation between species.
# 2.Model Building: Use the insights from the pair plot to inform feature selection and model training.
# 3.Outlier Analysis: Investigate potential outliers to understand their nature and decide on appropriate handling methods.
# By carefully analyzing the pair plot, you gain a deeper understanding of the relationships, distributions, and potential challenges within your dataset, guiding more informed decisions in subsequent analysis and modeling. If you have a specific dataset or additional variables you'd like to explore, let me know, and I can help tailor the analysis accordingly!

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from a pair plot can indeed help create a positive business impact, particularly when these insights are used to inform decision-making and strategy. Here are a few ways these insights can drive business value.Let's consider a hotel chain using these insights:
#
# Identifying Key Drivers:
#
# Booking Patterns: By analyzing cancellation patterns, the hotel can identify key drivers of cancellations and implement strategies to reduce them.
# Seasonal Trends: Understanding seasonal trends in bookings and cancellations can help in planning promotions and managing staff levels.
# Marketing and Sales:
#
# Targeted Campaigns: Use insights to target specific customer segments with tailored offers, such as discounts for early bookings or flexible cancellation policies for business travelers.
# Loyalty Programs: Develop loyalty programs that address the needs and preferences of different customer segments, enhancing customer retention.
# Operational Improvements:
#
# Staff Scheduling: Optimize staff schedules based on expected occupancy and cancellation rates, ensuring efficient operations and cost savings.
# Inventory Management: Adjust inventory and room availability dynamically based on predicted demand patterns.

# %% [markdown]
# #### Chart - 9  Correlation Heatmap

# %%
df.head()

# %%
# Correlation Heatmap visualization code
# Select only numeric columns before calculating correlations
numeric_df = df.select_dtypes(include=['number'])
# Correlation Heatmap visualization code
corr_matrix = numeric_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A heatmap is a data visualization technique that uses color to represent the values of a matrix or tabular data. It is particularly useful for understanding the magnitude of data values and identifying patterns, correlations, and anomalies in a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The hotel dataset includes features like lead_time, arrival_date_year, number_of_special_requests, adr (average daily rate), is_canceled, etc.
# 1.Feature Relationships:
#
# Positive Correlations:
# lead_time and adr: A high positive correlation between lead_time and adr suggests that longer lead times might be associated with higher average daily rates. This could indicate that guests booking well in advance tend to book higher-priced rooms.
# Negative Correlations:
# is_canceled and adr: A high negative correlation between is_canceled and adr might indicate that higher average daily rates are associated with lower cancellation rates. Guests who book more expensive rooms are less likely to cancel.
# Redundancy and Multicollinearity:
#
# High Correlation Values: Features with very high correlations (close to 1 or -1) might be redundant. For example, if lead_time and arrival_date_year have a high correlation, it suggests that one might predict the other. In modeling, you might consider removing or combining redundant features.
# Understanding Data Patterns:
#
# Guest Behavior: Insights from correlations can reveal guest behavior patterns. For example, if number_of_special_requests shows a strong correlation with adr, it may suggest that guests requesting more amenities tend to book higher-priced rooms.
# Operational Implications:
#
# Booking Patterns: If lead_time is strongly correlated with booking rates or adr, it might influence pricing strategies. For instance, hotels might offer discounts for longer lead times to increase bookings.
# Cancellation Management: Understanding the correlation between is_canceled and other features helps in managing cancellations. For example, if cancellations are more frequent with certain types of bookings, the hotel might adjust its policies or offer incentives to reduce cancellations.
# Feature Engineering:
#
# Data Preprocessing: High correlations among features might lead you to perform feature engineering to combine or transform variables. For example, if lead_time and arrival_date_year are highly correlated, you might create a new feature that captures seasonal effects.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Positive Impact: Effective use of insights can lead to better pricing strategies, improved cancellation management, and enhanced guest experiences, all of which drive revenue growth and operational efficiency.
#
# Negative Impact: Misinterpreting correlations or applying strategies without considering broader context (like seasonality or customer preferences) can lead to poor decision-making, potentially resulting in reduced bookings, customer dissatisfaction, and negative growth.
# To maximize positive impact, it’s crucial to:
#
# Validate Insights: Ensure correlations are understood in context and validated with additional data or analysis.
# Consider Context: Factor in external variables such as market conditions, seasonality, and customer preferences.
# Test Strategies: Implement changes on a smaller scale or through controlled experiments to gauge impact before full-scale rollout.
#
# By taking these precautions, hotels can leverage insights from heatmaps to drive positive business outcomes while avoiding pitfalls that could lead to negative growth. If you have specific scenarios or further details, I can provide more tailored advice!

# %% [markdown]
# #### Chart - 10
# Scatterplot

# %%
# Chart - 10 visualization code
# scatterplot showing Arrival date year and lead time
cdd = sns.scatterplot(x="arrival_date_year", y="lead_time", hue="hotel", data=df)

# %%
# scatterplot getting information about canceled request in lead time
cdd = sns.scatterplot(x="is_canceled", y="lead_time", hue="hotel", data=df)

# %%
#scatterplot getting information about canceled request in lead arrival year
cdd = sns.scatterplot(x="is_canceled", y="arrival_date_year", hue="hotel", data=df)

# %%
# using a DataFrame country for getting a scatter plot

# %%
pd.DataFrame(df.groupby('country').size())

# %%
cdd = sns.scatterplot(x="country", y="arrival_date_year", hue="hotel", data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A scatter plot is chosen because it provides a clear, visual representation of the relationships, patterns, and distinctions in your data, making it an invaluable tool for exploratory data analysis and interpretation. If you need a different type of visualization or have other data analysis goals, feel free to let me know!

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# To provide insights from a scatter plot using the hotel dataset, let’s create a hypothetical scenario where the scatter plot visualizes relationships among the following variables:
#
# is_canceled: Whether the booking was canceled (0 for no, 1 for yes)
#
# arrival_date_year: The year of arrival
# lead_time: The number of days between the booking and the arrival date
#
# hotel: The type of hotel (e.g., Resort Hotel or City Hotel)
#
# country: The country of origin of the guest
#
# By leveraging these insights, hotels can implement more effective booking policies, targeted marketing strategies, and operational adjustments to minimize cancellations and maximize occupancy and revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Positive Impact:
#
# Implementing flexible booking options and targeted marketing can increase customer satisfaction and occupancy rates.
# Differentiating strategies based on hotel type and guest origin helps optimize revenue and reduce cancellations.
# Adapting to yearly trends enables hotels to remain competitive and responsive to market changes.
# Negative Impact:Misinterpreting data or applying overly restrictive policies can lead to lower bookings and customer dissatisfaction.
# Validate Insights: Ensure that data interpretations are accurate and contextual.
# Customize Approaches: Tailor strategies to specific guest segments and hotel types.
# Remain Agile: Adapt policies based on external conditions and emerging trends.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# To increase hotel customers:
#
# 1.Improve Customer Service: Ensure staff provides excellent and personalized service.
#
# 2.Create a Comfortable Environment: Maintain clean, cozy rooms and offer appealing amenities.
#
# 3.Enhance Online Presence: Optimize your website, engage on social media, and encourage positive reviews.
#
# 4.Offer Special Deals: Provide attractive promotions and seasonal discounts.
#
# 5.Partner Locally: Collaborate with local businesses for joint promotions.
#
# 6.Respond to Feedback: Address guest complaints quickly and use feedback to improve.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
#  In conclusion, a hotel is essential for travelers, providing a crucial place to stay, relax, and conduct business. It offers comfort, convenience, and necessary amenities for both leisure and business guests, making it a key part of the travel experience.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
